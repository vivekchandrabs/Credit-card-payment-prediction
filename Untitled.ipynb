# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
data_set = pd.read_excel("default of credit card clients.xls")

# %%
data_set
# Out:
#               X1   X2         X3        X4   X5     X6     X7     X8     X9  \
# ID     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# 6          50000    1          1         2   37      0      0      0      0
# 7         500000    1          1         2   29      0      0      0      0
# 8         100000    2          2         2   23      0     -1     -1      0
# 9         140000    2          3         1   28      0      0      2      0
# 10         20000    1          3         2   35     -2     -2     -2     -2
# ...

# %%
data_set = np.array(data_set)

# %%
labels = data_set[0]

# %%
# data_set = pd.DataFrame(data_set, columns = labels)

# %%
x = np.delete(data_set, (0), axis=0)
x
# Out:
# array([[20000, 2, 2, ..., 0, 0, 1],
#        [120000, 2, 2, ..., 0, 2000, 1],
#        [90000, 2, 2, ..., 1000, 5000, 0],
#        ...,
#        [30000, 1, 2, ..., 2000, 3100, 1],
#        [80000, 1, 3, ..., 52964, 1804, 1],
#        [50000, 1, 2, ..., 1000, 1000, 1]], dtype=object)

# %%
data_set = pd.DataFrame(x, columns = labels)

# %%
data_set
# Out:
#       LIMIT_BAL SEX EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3 PAY_4 PAY_5  \
# 0         20000   2         2        1  24     2     2    -1    -1    -2
# 1        120000   2         2        2  26    -1     2     0     0     0
# 2         90000   2         2        2  34     0     0     0     0     0
# 3         50000   2         2        1  37     0     0     0     0     0
# 4         50000   1         2        1  57    -1     0    -1     0     0
# 5         50000   1         1        2  37     0     0     0     0     0
# 6        500000   1         1        2  29     0     0     0     0     0
# 7        100000   2         2        2  23     0    -1    -1     0     0
# 8        140000   2         3        1  28     0     0     2     0     0
# 9         20000   1         3        2  35    -2    -2    -2    -2    -1
# 10       200000   2         3        2  34     0     0     2     0     0
# 11       260000   2         1        2  51    -1    -1    -1    -1    -1
# ...

# %%
data = data_set.drop(['default payment next month'], axis=1)

# %%
target = data_set["default payment next month"]

# %%
data_set.corr('pearson')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
correlation
# Out:
# Empty DataFrame
# Columns: []
# Index: []
